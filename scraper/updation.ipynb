# %%
import pandas as pd
import time
import json
import requests
from splinter import Browser
from bs4 import BeautifulSoup as bs

# %%
#loading scraper declaring path
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
#setting up desired website
url = 'https://www.drivingsales.com/dealership-vendors'
browser.visit(url)
html = browser.html
soup = bs(html, 'html.parser')

# %%
#Final loop with all functions
itteration = ['#', '#tab-a', '#tab-b', '#tab-c', '#tab-d', '#tab-e', '#tab-f', '#tab-g', '#tab-h', '#tab-i', '#tab-j', '#tab-k', '#tab-l', '#tab-m', '#tab-n', '#tab-o', '#tab-p', '#tab-q', '#tab-r', '#tab-s', '#tab-t', '#tab-u', '#tab-v', '#tab-w', '#tab-x', '#tab-y', 'tab-z']
for i in itteration:
    html = browser.html
    soup = bs(html, 'html.parser')
    browser.click_link_by_partial_href(i)
    time.sleep(3)
    for p in pages:
        try:
            browser.click_link_by_partial_href(p)
            time.sleep(3)
        except: 
            print('This is the last page of this section')
            break
        html = browser.html
        soup = bs(html, 'html.parser')
        click_and_scrape()
# Out:
# tel:847-955-9740
# mailto:solutions@affinitiv.com
# https://www.affinitiv.com/
# tel:877-340-2677
# mailto:marketing@automate.com
# http://www.automate.com/
# tel:732-272-2377
# mailto:rana@automotivemastermind.com
# http://www.automotivemastermind.com/
# tel:888.348.4509
# mailto:info@adpearance.com
# https://adpearance.com/
# tel:949-716-7716
# no data here
# http://
# tel:919.744.3093
# mailto:info@albrightdigital.com
# http://albrightdigital.com
# tel:859-209-3694
# mailto:contact@myallcall.com
# https://www.myallcall.com/
# couldnt click
# no data here
# no data here
# http://0
# tel:(612) 353-4125
# mailto:sales@automotionweb.com
# http://www.automotiontv.com
# tel:877-499-5536
# mailto:DealerSupport@autoweb.com
# https://www.autoweb.com/dealers
# no data here
# no data here
# no data here
# no data here
# no data here
# no data here
# no data here
# no data here
# no data here
# no data here
# no data here
# no data here
# no data here
# no data here
# no data here
# ...

# %%
#looping through companies on each page
def click_and_scrape():
    html = browser.html
    soup = bs(html, 'html.parser')
    companies = soup.find_all('a', class_='product-name')
    for j in companies:
        x = j.text
        try:
            browser.click_link_by_partial_text(x)
            time.sleep(3)
            html = browser.html
            soup = bs(html, 'html.parser')
            name_ = str(soup.find('h2'))
            a_name.append(name_)
            company_info_scrape()
            time.sleep(3)
            browser.back()
            time.sleep(3)
        except:
            print('couldnt click')
        browser.click_link_by_partial_href(i)
        time.sleep(3)
        browser.click_link_by_partial_href(p)
        time.sleep(3)

# %%
#scraping the actual company info once on the page
def company_info_scrape():
    html = browser.html
    soup = bs(html, 'html.parser')
    c_info = soup.find_all('div', class_='data-point')
    for z in c_info:
        try:
            a = z.find('a')
            contact_info = a['href']
            a_info.append(contact_info)
            print(contact_info)
        except: 
            print("no data here")
            number_info.append("no data")

# %%
#navigating through numbered pages
pages = ['browse/1/10', 'browse/2/10', 'browse/3/10', 'browse/4/10', 'browse/5/10', 'browse/6/10', 'browse/7/10', 'browse/8/10', 'browse/9/10', 'browse/10/10', 'browse/11/10', 'browse/12/10', 'browse/13/10', 'browse/14/10', 'browse/15/10', 'browse/16/10', 'browse/17/10', 'browse/18/10', 'browse/19/10', 'browse/20/10', 'browse/21/10', 'browse/22/10']
for p in pages:
    try:
        browser.click_link_by_partial_href(p)
        time.sleep(3)
    except: 
        print('This is the last page of this section')
        break
    html = browser.html
    soup = bs(html, 'html.parser')
    click_and_scrape()
# Out:
# This is the last page of this section

# %%
#Build out dataframe
for doublew in number_name:
    if doublew == "None":
        number_name2.append('None')
    else:
        eff = doublew.split(">", 1)
        zed = eff.pop(1)
        dem = zed.split("<", 1)
        dem = dem.pop(0)
        number_name2.append(dem)
        print(eff)
print(number_name2)
# Out:
# ['321 Ignition', '700Credit LLC', '10 Foot Wave', '1Micro', 'None', '1to1 News, LLC', '2020 eConsulting - Website Design &amp; Search Engine Optimization', '2CSolutions LLC', '3 Birds Marketing', '3Mag Printing Ltd', '4Dealership', '5kMedia Web Services', '6 Month Loans Bad Credit', '800response', "'SMA Alliance'", '.', '11Sight LLC', '30,000 Feet View Automotive Consulting', '360 Payments', '360 Revo Inc.', '360VINspin', '445 Digital', '718 Car Lease', '718 Car Lease NY', '814 Interactive', '.BespokeChat']

# %%
exx = 1
for t in number_info:
    if exx == 1:
        number_info_phone.append(t)
        print(exx)
        exx +=1
    elif exx == 2:
        number_info_email.append(t)
        print(exx)
        exx +=1
    elif exx == 3:
        number_info_website.append(t)
        print(exx)
        exx = 1
# Out:
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3
# 1
# 2
# 3

# %%
#final dataframe
pd.DataFrame(rain, columns=["number_name, number_info_email, number_info_phone, number_info_website"])
number_df = pd.DataFrame(list(zip(number_name2, number_info_email, number_info_phone, number_info_website)), columns=['Name','Email', 'Phone', 'Website'])
number_df
# Out:
#                                                  Name  \
# 0                                        321 Ignition
# 1                                       700Credit LLC
# 2                                        10 Foot Wave
# 3                                              1Micro
# 4                                                None
# 5                                      1to1 News, LLC
# 6   2020 eConsulting - Website Design &amp; Search...
# 7                                     2CSolutions LLC
# 8                                   3 Birds Marketing
# 9                                   3Mag Printing Ltd
# 10                                        4Dealership
# 11                               5kMedia Web Services
# 12                           6 Month Loans Bad Credit
# 13                                        800response
# 14                                     'SMA Alliance'
# 15                                                  .
# ...
